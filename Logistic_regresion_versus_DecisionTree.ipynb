# %%
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict,cross_val_score
from sklearn import model_selection
from sklearn.model_selection import KFold

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
data = np.loadtxt("zbior1.txt")

# %%
X = data[:,:2]
y = data[:,2]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=100)

# %%
pipe = Pipeline([('standarization',StandardScaler()),
                 ('logisticreg',LogisticRegression())])
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standarization', StandardScaler(copy=True, with_mean=True, with_std=True)), ('logisticreg', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
model2 = DecisionTreeClassifier()

# %%
model2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
accuracy_score(pipe.predict(X_test),y_test)
# Out:
# 0.65000000000000002

# %%
accuracy_score(model2.predict(X_test),y_test)
# Out:
# 0.98999999999999999

# %%
y_test.mean()# p-stwo przy zgadywaniu "na ślepo"
# Out:
# 0.46999999999999997

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()
